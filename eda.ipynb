# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)

# %%
def eda(nombre_archivo):
    nombre_archivo = pd.read_csv(f'{nombre_archivo}.csv')

    print(f"\nANÁLISIS EXPLORATORIO DE DATOS")
    print(f"\n{nombre_archivo.shape[0]} FILAS Y {nombre_archivo.shape[1]} COLUMNAS")
    if nombre_archivo.duplicated().any():
        print("⚠️DUPLICADOS:", nombre_archivo.duplicated().sum())
    print("\nCOLUMNAS:\n", nombre_archivo.columns, "\n")
   
    contador = 0
    for i in nombre_archivo.columns:
        print("\n-----------------------------------------------------------------")
        print("🟦 COLUMNA", contador, ": ", i)
        nulos = nombre_archivo[i].isnull()
        if nulos.any():
            print("\n\n⚠️NULOS:")
            print(nulos.sum())
        else:
            print("\nNO HAY VALORES NULOS")
        if nombre_archivo[i].value_counts().count() < 30:
            print(nombre_archivo[i].value_counts().count(), "VALORES:")
            print(nombre_archivo[i].value_counts().sort_values())
        else:
            print("\n⚪NUMEROSOS VALORES, POR EJEMPLO:")
            print(nombre_archivo[i].sample(5))
        contador +=1
    print("--------------------------------------------------------------------")

    display(nombre_archivo.head())
    display(nombre_archivo.tail())
    display(nombre_archivo.sample(5))


    print("\nINFORMACIÖN GENERAL:")
    print(nombre_archivo.info())

    print("\nTIPOS DE DATOS:")
    print(nombre_archivo.dtypes)

    print("\nDESCRIPCIÓN ESTADÍSTICA SIN LA COLUMNA DE ID 'Loyalty Number' (ya que no es verdaderamente numérica):")
    descripcion = nombre_archivo.describe(include='all').round(2).T
    descripcion_sin_falsas_numericas = descripcion.drop(['Loyalty Number', 'Year', 'Month'], errors='ignore')
    display(descripcion_sin_falsas_numericas)

# %%
eda('Customer Flight Activity')
# Out:
# ANÁLISIS EXPLORATORIO DE DATOS
#
# 405624 FILAS Y 10 COLUMNAS
# ⚠️DUPLICADOS: 1864
#
# COLUMNAS:
#  Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')
#
#
# -----------------------------------------------------------------
# 🟦 COLUMNA 0 :  Loyalty Number
#
# NO HAY VALORES NULOS
#
# ⚪NUMEROSOS VALORES, POR EJEMPLO:
# 4907      362841
# 365190    645986
# 80121     276967
# 124489    430569
# 131907    397787
# Name: Loyalty Number, dtype: int64
#
# -----------------------------------------------------------------
# 🟦 COLUMNA 1 :  Year
#
# NO HAY VALORES NULOS
# 2 VALORES:
# Year
# 2017    202812
# 2018    202812
# Name: count, dtype: int64
#
# -----------------------------------------------------------------
# 🟦 COLUMNA 2 :  Month
#
# NO HAY VALORES NULOS
# 12 VALORES:
# Month
# 1     33802
# 9     33802
# ...

# %%
eda('Customer Loyalty History')
# Out:
# ANÁLISIS EXPLORATORIO DE DATOS
#
# 16737 FILAS Y 16 COLUMNAS
#
# COLUMNAS:
#  Index(['Loyalty Number', 'Country', 'Province', 'City', 'Postal Code',
#        'Gender', 'Education', 'Salary', 'Marital Status', 'Loyalty Card',
#        'CLV', 'Enrollment Type', 'Enrollment Year', 'Enrollment Month',
#        'Cancellation Year', 'Cancellation Month'],
#       dtype='object')
#
#
# -----------------------------------------------------------------
# 🟦 COLUMNA 0 :  Loyalty Number
#
# NO HAY VALORES NULOS
#
# ⚪NUMEROSOS VALORES, POR EJEMPLO:
# 12357    765989
# 1633     388448
# 6602     375162
# 7150     512179
# 14768    696431
# Name: Loyalty Number, dtype: int64
#
# -----------------------------------------------------------------
# 🟦 COLUMNA 1 :  Country
#
# NO HAY VALORES NULOS
# 1 VALORES:
# Country
# Canada    16737
# Name: count, dtype: int64
#
# -----------------------------------------------------------------
# 🟦 COLUMNA 2 :  Province
#
# NO HAY VALORES NULOS
# 11 VALORES:
# ...
